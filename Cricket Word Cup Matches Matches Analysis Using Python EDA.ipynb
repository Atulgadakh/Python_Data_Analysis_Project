# %% [markdown]
# #Cricket world Cup 2023 Matches Analysis using Python EDA

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import os

# %%
os.chdir(r"C:\Users\hp\Desktop\New folder (2)")

# %%
#Data Import

# %%
cricket=pd.read_csv("CWC2023.csv")

# %%
cricket.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023    2:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023    2:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  ...  \
# 0       England   NewZealand   NewZealand         Field      282  ...
# 1      Pakistan  Netherlands  Netherlands         Field      286  ...
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156  ...
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428  ...
# 4     Australia        India    Australia           Bat      199  ...
#
#    No Balls B  Penalty B  Extras B   Wining Team     Margin  \
# ...

# %%
#Data Cleaning

# %%
cricket.isnull().sum().sum()
# Out:
# 0

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Match ID          48 non-null     int64
#  1   Match Date        48 non-null     object
#  2   Match Time        48 non-null     object
#  3   City              48 non-null     object
#  4   Stadium           48 non-null     object
#  5   Team A            48 non-null     object
#  6   Team B            48 non-null     object
#  7   Toss Winner       48 non-null     object
#  8   Toss Decision     48 non-null     object
#  9   Score A           48 non-null     int64
#  10  Wickets A         48 non-null     int64
#  11  Overs Played A    48 non-null     float64
#  12  Maiden Overs A    48 non-null     int64
#  13  4s A              48 non-null     int64
#  14  6s A              48 non-null     int64
#  15  Boundaries A      48 non-null     int64
# ...

# %%
#Statistical Analysis

# %%
cricket.describe()
# Out:
#        Match ID     Score A  Wickets A  Overs Played A  Maiden Overs A  \
# count     48.00   48.000000  48.000000       48.000000       48.000000
# mean      24.50  282.562500   8.104167       47.354167        1.687500
# std       14.00   76.709429   2.185441        5.048866        1.573129
# min        1.00  142.000000   3.000000       31.300000        0.000000
# 25%       12.75  237.250000   7.000000       47.025000        0.750000
# 50%       24.50  280.500000   9.000000       50.000000        1.000000
# 75%       36.25  347.250000  10.000000       50.000000        2.250000
# max       48.00  428.000000  10.000000       50.000000        7.000000
#
#             4s A       6s A  Boundaries A  Runrate A  Leg Byes A  ...  \
# count  48.000000  48.000000     48.000000  48.000000    48.00000  ...
# mean   25.916667   7.833333     33.750000   5.947708     2.87500  ...
# std     8.068413   5.292843     11.699245   1.305108     2.97954  ...
# ...

# %%
cricket.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023    2:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023    2:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  ...  \
# 0       England   NewZealand   NewZealand         Field      282  ...
# 1      Pakistan  Netherlands  Netherlands         Field      286  ...
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156  ...
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428  ...
# 4     Australia        India    Australia           Bat      199  ...
#
#    No Balls B  Penalty B  Extras B   Wining Team     Margin  \
# ...

# %%
#Exploratory Data Analysis(EDA)

# %%
#Quetion- Display who win most time Man of The Match Title

# %%
cricket["Man of the Match"].value_counts()[0:10]
# Out:
# Man of the Match
# Mohammed Shami           3
# Travis Head              3
# Rohit Sharma             2
# Glenn Maxwell            2
# Virat Kohli              2
# Adam Zampa               2
# Fakhar Zaman             2
# Quinton de Kock          2
# Rassie van der Dussen    2
# Mohammad Nabi            1
# Name: count, dtype: int64

# %%
plt.pie(cricket["Man of the Match"].value_counts()[0:10],labels=(cricket["Man of the Match"].value_counts()[0:10].keys()),autopct="%0.1f%%")
plt.title("Distribution of Player of the Match in Cricket Matches")
plt.show()

# %%
cricket.groupby(['Toss Decision', 'Wining Team']).size().reset_index(name='Count')
# Out:
#    Toss Decision   Wining Team  Count
# 0            Bat   Afghanistan      2
# 1            Bat     Australia      4
# 2            Bat       England      2
# 3            Bat         India      6
# 4            Bat   Netherlands      1
# 5            Bat      Pakistan      2
# 6            Bat  South Africa      3
# 7            Bat     Sri Lanka      2
# 8          Field   Afghanistan      2
# 9          Field     Australia      5
# 10         Field    Bangladesh      2
# 11         Field       England      1
# 12         Field         India      4
# 13         Field   Netherlands      1
# 14         Field    NewZealand      5
# 15         Field      Pakistan      2
# 16         Field  South Africa      4

# %%
# Question- Display which team win toss most time

# %%
cricket["Toss Winner"].value_counts()
# Out:
# Toss Winner
# England         7
# NewZealand      5
# Netherlands     5
# Bangladesh      5
# Australia       5
# Afghanistan     5
# India           5
# Sri Lanka       4
# Pakistan        4
# South Africa    3
# Name: count, dtype: int64

# %%
plt.pie(cricket["Toss Winner"].value_counts(),labels=(cricket["Toss Winner"].value_counts().keys()),autopct="%0.1f%%",colors=["Red","blue","green","yellow","orange","red","blue","orange","yellow","green"])
plt.title("Distribution of Toss Winners in Cricket Matches")
plt.show()

# %%
# Question-Display the result margin between two teams

# %%
winner_margin=cricket['Score A'] - cricket['Score B']
winner_margin
# Out:
# 0      -1
# 1      81
# 2      -2
# 3     102
# 4      -2
# 5      99
# 6     137
# 7      -1
# 8      -1
# 9     134
# 10     -3
# 11     -1
# 12     69
# 13     -6
# 14     38
# 15    149
# 16     -5
# 17     62
# 18     -1
# 19    229
# 20     -1
# 21     -4
# 22    149
# 23    309
# 24     -4
# 25     -1
# 26      5
# 27    -87
# 28    100
# 29     -1
# 30      1
# 31    190
# 32    302
# 33      2
# 34    201
# 35     33
# 36    243
# 37     -3
# 38      2
# 39   -160
# 40     -1
# 41     -3
# 42     -1
# 43    -93
# 44    160
# 45     70
# 46      3
# 47     -1
# dtype: int64

# %%
#Question - display the record which team most run score

# %%
cricket.sort_values("Score A",ascending=False)
# Out:
#     Match ID  Match Date Match Time         City  \
# 3          4  07-10-2023    2:00 PM        Delhi
# 44        45  12-11-2023    2:00 PM    Bangalore
# 34        35  04-11-2023    2:00 PM    Bangalore
# 19        20  21-10-2023    2:00 PM       Mumbai
# 23        24  25-10-2023    2:00 PM        Delhi
# 45        46  15-11-2023    2:00 PM       Mumbai
# 26        27  28-10-2023   10:30 AM  Dharamshala
# 22        23  24-10-2023    2:00 PM       Mumbai
# 17        18  20-10-2023    2:00 PM    Bangalore
# 6          7  10-10-2023   10:30 AM  Dharamshala
# 32        33  02-11-2023    2:00 PM       Mumbai
# 31        32  01-11-2023    2:00 PM         Pune
# 7          8  10-10-2023    2:00 PM    Hyderabad
# 36        37  05-11-2023    2:00 PM      Kolkata
# 5          6  09-10-2023    2:00 PM    Hyderabad
# 9         10  12-10-2023    2:00 PM      Lucknow
# 42        43  11-11-2023    2:00 PM         Pune
# 38        39  07-11-2023    2:00 PM       Mumbai
# ...

# %%
# Question- Display those record teams wins larger margin

# %%
cricket.sort_values("Margin",ascending=False)
# Out:
#     Match ID  Match Date Match Time         City  \
# 5          6  09-10-2023    2:00 PM    Hyderabad
# 43        44  11-11-2023    2:00 PM      Kolkata
# 0          1  05-10-2023    2:00 PM    Ahmedabad
# 27        28  28-10-2023    2:00 PM      Kolkata
# 1          2  06-10-2023    2:00 PM    Hyderabad
# 10        11  13-10-2023    2:00 PM      Chennai
# 42        43  11-11-2023    2:00 PM         Pune
# 21        22  23-10-2023    2:00 PM      Chennai
# 24        25  26-10-2023    2:00 PM    Bangalore
# 8          9  11-10-2023    2:00 PM        Delhi
# 45        46  15-11-2023    2:00 PM       Mumbai
# 11        12  14-10-2023    2:00 PM    Ahmedabad
# 33        34  03-11-2023   10:30 AM      Lucknow
# 16        17  19-10-2023    2:00 PM         Pune
# 30        31  31-11-2023    2:00 PM      Kolkata
# 29        30  30-10-2023    2:00 PM         Pune
# 17        18  20-10-2023    2:00 PM    Bangalore
# 4          5  08-10-2023    2:00 PM      Chennai
# ...

# %%
cricket["Man of the Match"].value_counts()[0:10]
# Out:
# Man of the Match
# Mohammed Shami           3
# Travis Head              3
# Rohit Sharma             2
# Glenn Maxwell            2
# Virat Kohli              2
# Adam Zampa               2
# Fakhar Zaman             2
# Quinton de Kock          2
# Rassie van der Dussen    2
# Mohammad Nabi            1
# Name: count, dtype: int64

# %%
cricket.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023    2:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023    2:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  ...  \
# 0       England   NewZealand   NewZealand         Field      282  ...
# 1      Pakistan  Netherlands  Netherlands         Field      286  ...
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156  ...
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428  ...
# 4     Australia        India    Australia           Bat      199  ...
#
#    No Balls B  Penalty B  Extras B   Wining Team     Margin  \
# ...

# %%
# Display those record Toss winner tams wins the match

# %%
cricket[cricket["Toss Winner"] == cricket["Wining Team"]].head()
# Out:
#     Match ID  Match Date Match Time         City                    Stadium  \
# 0          1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 2          3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 10        11  13-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
# 11        12  14-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 20        21  22-10-2023    2:00 PM  Dharamshala               HPCA Stadium
#
#          Team A      Team B Toss Winner Toss Decision  Score A  ...  \
# 0       England  NewZealand  NewZealand         Field      282  ...
# 2   Afghanistan  Bangladesh  Bangladesh         Field      156  ...
# 10   Bangladesh  NewZealand  NewZealand         Field      245  ...
# 11     Pakistan       India       India         Field      191  ...
# 20   NewZealand       India       India         Field      273  ...
#
#     No Balls B  Penalty B  Extras B  Wining Team     Margin  \
# ...

# %%
cricket
# Out:
#     Match ID  Match Date Match Time         City  \
# 0          1  05-10-2023    2:00 PM    Ahmedabad
# 1          2  06-10-2023    2:00 PM    Hyderabad
# 2          3  07-10-2023    2:00 PM  Dharamshala
# 3          4  07-10-2023    2:00 PM        Delhi
# 4          5  08-10-2023    2:00 PM      Chennai
# 5          6  09-10-2023    2:00 PM    Hyderabad
# 6          7  10-10-2023   10:30 AM  Dharamshala
# 7          8  10-10-2023    2:00 PM    Hyderabad
# 8          9  11-10-2023    2:00 PM        Delhi
# 9         10  12-10-2023    2:00 PM      Lucknow
# 10        11  13-10-2023    2:00 PM      Chennai
# 11        12  14-10-2023    2:00 PM    Ahmedabad
# 12        13  15-10-2023    2:00 PM        Delhi
# 13        14  16-10-2023    2:00 PM      Lucknow
# 14        15  17-10-2023    2:00 PM  Dharamshala
# 15        16  18-10-2023    2:00 PM      Chennai
# 16        17  19-10-2023    2:00 PM         Pune
# 17        18  20-10-2023    2:00 PM    Bangalore
# ...

# %%
#Display those record teams take field frist

# %%
field_frist=cricket[cricket["Toss Decision"] == "Field"]
field_frist.head()
# Out:
#    Match ID  Match Date Match Time         City  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad
# 1         2  06-10-2023    2:00 PM    Hyderabad
# 2         3  07-10-2023    2:00 PM  Dharamshala
# 3         4  07-10-2023    2:00 PM        Delhi
# 5         6  09-10-2023    2:00 PM    Hyderabad
#
#                               Stadium        Team A       Team B  Toss Winner  \
# 0               Narendra Modi Stadium       England   NewZealand   NewZealand
# 1                        Eden Gardens      Pakistan  Netherlands  Netherlands
# 2                        HPCA Stadium   Afghanistan   Bangladesh   Bangladesh
# 3                Arun Jaitley Stadium  South Africa    Sri Lanka    Sri Lanka
# 5  Rajiv Gandhi International Stadium    NewZealand  Netherlands  Netherlands
#
#   Toss Decision  Score A  ...  No Balls B  Penalty B  Extras B   Wining Team  \
# 0         Field      282  ...           0          0         6    NewZealand
# ...

# %%
# Question = Display those record team win the toss and take field and win the match

# %%
field_frist["Wining Team"].value_counts()
# Out:
# Wining Team
# NewZealand      5
# Australia       5
# South Africa    4
# India           4
# Pakistan        2
# Bangladesh      2
# Afghanistan     2
# England         1
# Netherlands     1
# Name: count, dtype: int64

# %%
plt.pie(field_frist["Wining Team"].value_counts(),labels=(field_frist["Wining Team"].value_counts().keys()),autopct="%0.1f%%")
plt.title("Most time winner with field frist")
plt.show()

# %%
field_frist.head()
# Out:
#    Match ID  Match Date Match Time         City  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad
# 1         2  06-10-2023    2:00 PM    Hyderabad
# 2         3  07-10-2023    2:00 PM  Dharamshala
# 3         4  07-10-2023    2:00 PM        Delhi
# 5         6  09-10-2023    2:00 PM    Hyderabad
#
#                               Stadium        Team A       Team B  Toss Winner  \
# 0               Narendra Modi Stadium       England   NewZealand   NewZealand
# 1                        Eden Gardens      Pakistan  Netherlands  Netherlands
# 2                        HPCA Stadium   Afghanistan   Bangladesh   Bangladesh
# 3                Arun Jaitley Stadium  South Africa    Sri Lanka    Sri Lanka
# 5  Rajiv Gandhi International Stadium    NewZealand  Netherlands  Netherlands
#
#   Toss Decision  Score A  ...  No Balls B  Penalty B  Extras B   Wining Team  \
# 0         Field      282  ...           0          0         6    NewZealand
# ...

# %%
# Question = Display Those records team win the toss takes field first and win man of the match award

# %%
field_frist["Man of the Match"].value_counts()[0:5]
# Out:
# Man of the Match
# Travis Head        2
# Mohammed Shami     2
# Rachin Ravindra    1
# Saud Shakeel       1
# Trent Boult        1
# Name: count, dtype: int64

# %%
field_frist["Man of the Match"].value_counts()[0:5].keys()
# Out:
# Index(['Travis Head', 'Mohammed Shami', 'Rachin Ravindra', 'Saud Shakeel',
#        'Trent Boult'],
#       dtype='object', name='Man of the Match')

# %%
plt.barh(field_frist["Man of the Match"].value_counts()[0:5].keys(),field_frist["Man of the Match"].value_counts()[0:5],color=["Red","yellow","green","orange","yellow"])
plt.show()

# %%
# Question= Display those record teams win the toss and take the bat frist decision

# %%
batting_frist=cricket[cricket["Toss Decision"] == "Bat"]
batting_frist.head(3)
# Out:
#    Match ID  Match Date Match Time       City  \
# 4         5  08-10-2023    2:00 PM    Chennai
# 7         8  10-10-2023    2:00 PM  Hyderabad
# 8         9  11-10-2023    2:00 PM      Delhi
#
#                               Stadium       Team A    Team B  Toss Winner  \
# 4           M. A. Chidambaram Stadium    Australia     India    Australia
# 7  Rajiv Gandhi International Stadium    Sri Lanka  Pakistan    Sri Lanka
# 8                Arun Jaitley Stadium  Afghanistan     India  Afghanistan
#
#   Toss Decision  Score A  ...  No Balls B  Penalty B  Extras B  Wining Team  \
# 4           Bat      199  ...           0          0        12        India
# 7           Bat      344  ...           1          0        14     Pakistan
# 8           Bat      272  ...           2          0        15        India
#
#       Margin  Man of the Match        Umpire 1               Umpire 2  \
# 4  6 wickets          KL Rahul  Chris Gaffaney  Richard Kettleborough
# ...

# %%
man_of_the_match=batting_frist.sort_values(by="Man of the Match",ascending=False)
man_of_the_match.head()
# Out:
#     Match ID  Match Date Match Time       City  \
# 16        17  19-10-2023    2:00 PM       Pune
# 36        37  05-11-2023    2:00 PM    Kolkata
# 46        47  16-11-2023    2:00 PM    Kolkata
# 25        26  27-10-2023    2:00 PM    Chennai
# 44        45  12-11-2023    2:00 PM  Bangalore
#
#                                     Stadium      Team A        Team B  \
# 16  Maharashtra Cricket Association Stadium  Bangladesh         India
# 36                             Eden Gardens       India  South Africa
# 46                             Eden Gardens   Australia  South Africa
# 25                M. A. Chidambaram Stadium    Pakistan  South Africa
# 44                   M. Chinnaswamy Stadium       India   Netherlands
#
#      Toss Winner Toss Decision  Score A  ...  No Balls B  Penalty B  Extras B  \
# 16    Bangladesh           Bat      256  ...           0          0         6
# 36         India           Bat      326  ...           2          0        26
# ...

# %%
# Question = Display those record who win most time man of the match award with bat frist

# %%
man_of_the_match["Man of the Match"][0:10]
# Out:
# 16               Virat Kohli
# 36               Virat Kohli
# 46               Travis Head
# 25            Tabraiz Shamsi
# 44              Shreyas Iyer
# 18    Sadeera Samarawickrama
# 8               Rohit Sharma
# 41     Rassie van der Dussen
# 22           Quinton de Kock
# 27         Paul van Meekeren
# Name: Man of the Match, dtype: object

# %%
plt.pie(man_of_the_match["Man of the Match"].value_counts()[0:10],labels=(man_of_the_match["Man of the Match"].value_counts()[0:10].keys()),autopct="%0.1f%%")
plt.title("Most time player of the match with bat frist")
plt.show()

# %%
# Question = Display win margin between two teams

# %%
result_margin=batting_frist["Score A"] - batting_frist["Score B"]
result_margin
# Out:
# 4      -2
# 7      -1
# 8      -1
# 13     -6
# 16     -5
# 18     -1
# 21     -4
# 22    149
# 23    309
# 24     -4
# 25     -1
# 27    -87
# 30      1
# 33      2
# 36    243
# 38      2
# 39   -160
# 41     -3
# 43    -93
# 44    160
# 45     70
# 46      3
# dtype: int64

# %%
batting_frist["Wining Team"]
# Out:
# 4            India
# 7         Pakistan
# 8            India
# 13       Australia
# 16           India
# 18       Sri Lanka
# 21     Afghanistan
# 22    South Africa
# 23       Australia
# 24       Sri Lanka
# 25    South Africa
# 27     Netherlands
# 30        Pakistan
# 33     Afghanistan
# 36           India
# 38       Australia
# 39         England
# 41    South Africa
# 43         England
# 44           India
# 45           India
# 46       Australia
# Name: Wining Team, dtype: object

# %%
plt.figure(figsize=(11,7))
plt.bar(batting_frist["Wining Team"],result_margin,color=["orange"])
plt.title("Winning Margin between two teams")
plt.show()

# %%
batting_frist["Wining Team"].value_counts()
# Out:
# Wining Team
# India           6
# Australia       4
# South Africa    3
# Pakistan        2
# Sri Lanka       2
# Afghanistan     2
# England         2
# Netherlands     1
# Name: count, dtype: int64

# %%
plt.pie(batting_frist["Wining Team"].value_counts(),labels=(batting_frist["Wining Team"].value_counts().keys()),autopct="%0.1f%%")
plt.title("Distribution of Winners in Cricket Matches with batting frist")
# Out:
# Text(0.5, 1.0, 'Distribution of Winners in Cricket Matches with batting frist')

# %%
plt.bar(batting_frist["Wining Team"][0:7],batting_frist["Score A"][0:7],color=["orange"])
plt.xlabel("Winning Team")
plt.ylabel("Score A")
plt.title("Top 7 Teams' Scores when Batting First")
plt.show()
