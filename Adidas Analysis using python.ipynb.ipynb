# %% [markdown]
# # Analyse the Adidas Data using Python EDA

# %%
#importing libreries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
os.chdir(r"C:\Users\hp\Desktop\csv2")

# %%
#import Data
Adidas=pd.read_csv("Adidas.csv")

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast    New York
# 1     Foot Locker      1185732     1/2/2020  Northeast    New York
# 2     Foot Locker      1185732     1/3/2020  Northeast    New York
# 3     Foot Locker      1185732     1/4/2020  Northeast    New York
# 4     Foot Locker      1185732     1/5/2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833    3/14/2021       West  California
# 4108       Kohl's      1189833    3/15/2021       West  California
# 4109       Kohl's      1189833    3/16/2021       West  California
# 4110       Kohl's      1189833    3/17/2021       West  California
# 4111       Kohl's      1189833    3/18/2021       West  California
#
#              City                    Product Price per Unit Units Sold  \
# 0        New York      Men's Street Footwear        $50.00       1,200
# ...

# %%
#data Cleaning

# %%
Adidas.isnull()
# Out:
#       Retailer  Retailer ID  Invoice Date  Region  State   City  Product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 4107     False        False         False   False  False  False    False
# 4108     False        False         False   False  False  False    False
# 4109     False        False         False   False  False  False    False
# 4110     False        False         False   False  False  False    False
# 4111     False        False         False   False  False  False    False
#
#       Price per Unit  Units Sold  Total Sales  Operating Profit  \
# ...

# %%
Adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4112 entries, 0 to 4111
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          4112 non-null   object
#  1   Retailer ID       4112 non-null   int64
#  2   Invoice Date      4112 non-null   object
#  3   Region            4112 non-null   object
#  4   State             4112 non-null   object
#  5   City              4112 non-null   object
#  6   Product           4112 non-null   object
#  7   Price per Unit    4112 non-null   object
#  8   Units Sold        4112 non-null   object
#  9   Total Sales       4112 non-null   object
#  10  Operating Profit  4112 non-null   object
#  11  Operating Margin  4112 non-null   object
#  12  Sales Method      4112 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 417.8+ KB

# %%
#change datatypes of an column

# %%
Adidas["Total Sales"] = Adidas["Total Sales"].str.replace('[\$,]', '', regex=True).astype(float)

# %%
Adidas["Price per Unit"] = Adidas["Price per Unit"].str.replace('[\$,]', '', regex=True).astype(float)

# %%
Adidas["Units Sold"] = Adidas["Units Sold"].str.replace('[\$,]', '', regex=True).astype(float)

# %%
Adidas["Invoice Date"] = pd.to_datetime(Adidas["Invoice Date"])

# %%
#check the values null or not

# %%
Adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4112 entries, 0 to 4111
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          4112 non-null   object
#  1   Retailer ID       4112 non-null   int64
#  2   Invoice Date      4112 non-null   datetime64[ns]
#  3   Region            4112 non-null   object
#  4   State             4112 non-null   object
#  5   City              4112 non-null   object
#  6   Product           4112 non-null   object
#  7   Price per Unit    4112 non-null   float64
#  8   Units Sold        4112 non-null   float64
#  9   Total Sales       4112 non-null   float64
#  10  Operating Profit  4112 non-null   object
#  11  Operating Margin  4112 non-null   object
#  12  Sales Method      4112 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 417.8+ KB

# %%
#sort the total sales

# %%
sorting=Adidas.sort_values(by="Total Sales", ascending=False)

# %%
sorting
# Out:
#            Retailer  Retailer ID Invoice Date     Region      State  \
# 1394        Walmart      1128299   2021-06-17  Southeast    Florida
# 1970      West Gear      1128299   2021-06-17      South  Louisiana
# 1395        Walmart      1128299   2021-07-16  Southeast    Florida
# 1971      West Gear      1128299   2021-07-16      South  Louisiana
# 1977      West Gear      1128299   2021-08-17      South  Louisiana
# ...             ...          ...          ...        ...        ...
# 3972  Sports Direct      1197831   2020-08-04      South      Texas
# 3962  Sports Direct      1197831   2020-07-25      South      Texas
# 3966  Sports Direct      1197831   2020-07-29      South      Texas
# 1019    Foot Locker      1185732   2021-06-05    Midwest   Nebraska
# 1025    Foot Locker      1185732   2021-06-11    Midwest   Nebraska
#
#              City                    Product  Price per Unit  Units Sold  \
# 1394      Orlando            Women's Apparel           110.0       750.0
# ...

# %%
#creating new column of month on the basis of date column

# %%
sorting["Invoice Date"].dt.month_name()
# Out:
# 1394      June
# 1970      June
# 1395      July
# 1971      July
# 1977    August
#          ...
# 3972    August
# 3962      July
# 3966      July
# 1019      June
# 1025      June
# Name: Invoice Date, Length: 4112, dtype: object

# %%
#sort the data

# %%
sorting["Total Sales"]
# Out:
# 1394    825000.0
# 1970    825000.0
# 1395    810000.0
# 1971    810000.0
# 1977    807500.0
#           ...
# 3972      5125.0
# 3962      4899.0
# 3966      4750.0
# 1019         0.0
# 1025         0.0
# Name: Total Sales, Length: 4112, dtype: float64

# %%
Adidas.dropna()
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast    New York
# 1     Foot Locker      1185732   2020-01-02  Northeast    New York
# 2     Foot Locker      1185732   2020-01-03  Northeast    New York
# 3     Foot Locker      1185732   2020-01-04  Northeast    New York
# 4     Foot Locker      1185732   2020-01-05  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833   2021-03-14       West  California
# 4108       Kohl's      1189833   2021-03-15       West  California
# 4109       Kohl's      1189833   2021-03-16       West  California
# 4110       Kohl's      1189833   2021-03-17       West  California
# 4111       Kohl's      1189833   2021-03-18       West  California
#
#              City                    Product  Price per Unit  Units Sold  \
# 0        New York      Men's Street Footwear            50.0      1200.0
# ...

# %%
#first five record of Adidas data

# %%
Adidas.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#   Operating Profit Operating Margin Sales Method
# 0        $300,000               50%     In-store
# ...

# %%
#last five record of Adidas data

# %%
Adidas.tail()
# Out:
#      Retailer  Retailer ID Invoice Date Region       State         City  \
# 4107   Kohl's      1189833   2021-03-14   West  California  Los Angeles
# 4108   Kohl's      1189833   2021-03-15   West  California  Los Angeles
# 4109   Kohl's      1189833   2021-03-16   West  California  Los Angeles
# 4110   Kohl's      1189833   2021-03-17   West  California  Los Angeles
# 4111   Kohl's      1189833   2021-03-18   West  California  Los Angeles
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# 4107    Men's Athletic Footwear            43.0       195.0       8385.0
# 4108    Women's Street Footwear            44.0       169.0       7436.0
# 4109  Women's Athletic Footwear            41.0       152.0       6232.0
# 4110              Men's Apparel            46.0       113.0       5198.0
# 4111            Women's Apparel            41.0       176.0       7216.0
#
#      Operating Profit Operating Margin Sales Method
# ...

# %%
Adidas["Retailer"]
# Out:
# 0       Foot Locker
# 1       Foot Locker
# 2       Foot Locker
# 3       Foot Locker
# 4       Foot Locker
#            ...
# 4107         Kohl's
# 4108         Kohl's
# 4109         Kohl's
# 4110         Kohl's
# 4111         Kohl's
# Name: Retailer, Length: 4112, dtype: object

# %%
#group the data of retailer column

# %%
Adidas["Retailer"].value_counts()
# Out:
# Retailer
# Foot Locker      1153
# West Gear        1026
# Sports Direct     796
# Kohl's            444
# Amazon            405
# Walmart           288
# Name: count, dtype: int64

# %%
Adidas["Total Sales"]
# Out:
# 0       600000.0
# 1       500000.0
# 2       400000.0
# 3       382500.0
# 4       540000.0
#           ...
# 4107      8385.0
# 4108      7436.0
# 4109      6232.0
# 4110      5198.0
# 4111      7216.0
# Name: Total Sales, Length: 4112, dtype: float64

# %%
Adidas.sort_values(by=["Total Sales"] , ascending=True)
# Out:
#            Retailer  Retailer ID Invoice Date     Region      State  \
# 1019    Foot Locker      1185732   2021-06-05    Midwest   Nebraska
# 1025    Foot Locker      1185732   2021-06-11    Midwest   Nebraska
# 3966  Sports Direct      1197831   2020-07-29      South      Texas
# 3962  Sports Direct      1197831   2020-07-25      South      Texas
# 3972  Sports Direct      1197831   2020-08-04      South      Texas
# ...             ...          ...          ...        ...        ...
# 1401        Walmart      1128299   2021-08-17  Southeast    Florida
# 1971      West Gear      1128299   2021-07-16      South  Louisiana
# 1395        Walmart      1128299   2021-07-16  Southeast    Florida
# 1970      West Gear      1128299   2021-06-17      South  Louisiana
# 1394        Walmart      1128299   2021-06-17  Southeast    Florida
#
#              City                    Product  Price per Unit  Units Sold  \
# 1019        Omaha  Women's Athletic Footwear            35.0         0.0
# ...

# %%
#line chart region wise sale

# %%
ypoints = np.array(Adidas["Total Sales"][0:15])
xpoints = np.array(Adidas["Region"])
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.plot(ypoints,ypoints, linestyle = 'dotted',color="r")
plt.show()

# %%
#types of retailer using graph chart

# %%
plt.figure(figsize=(8,8))
plt.bar(list(Adidas["Retailer"].value_counts().keys()),list(Adidas["Retailer"].value_counts()),color=["red","blue","orange","gray","yellow","orange"])
plt.title("Types of Retailer")
plt.show()

# %%
#Analyse the product distribution using pie chart

# %%
plt.figure(figsize=(5, 5))
plt.pie(list(Adidas["Product"].value_counts()), labels=list(Adidas["Product"].value_counts().keys()), autopct="%0.1f%%")
plt.title("Product Distribution")
plt.show()

# %%
#count the regions of Adidas data

# %%
Adidas["Region"].value_counts()
# Out:
# Region
# West         1016
# Northeast    1008
# Midwest       936
# South         648
# Southeast     504
# Name: count, dtype: int64

# %%
#Types of region

# %%
plt.figure(figsize=(7,7))
plt.bar(list(Adidas["Region"].value_counts().keys()),list(Adidas["Region"].value_counts()),color=["orange","grey","orange","gray","orange"])
plt.title("Regions")
plt.show()

# %%
#states in the data

# %%
Adidas["State"].value_counts()
# Out:
# State
# California        224
# New York          216
# Texas             216
# Florida           144
# Vermont            72
# North Dakota       72
# South Carolina     72
# North Carolina     72
# Ohio               72
# Kentucky           72
# Mississippi        72
# Arkansas           72
# Oklahoma           72
# Kansas             72
# South Dakota       72
# Iowa               72
# Massachusetts      72
# Georgia            72
# Indiana            72
# West Virginia      72
# Maryland           72
# Delaware           72
# New Jersey         72
# Connecticut        72
# Rhode Island       72
# Wisconsin          72
# Arizona            72
# New Mexico         72
# Alabama            72
# Illinois           72
# Pennsylvania       72
# Nevada             72
# Colorado           72
# Washington         72
# Minnesota          72
# Montana            72
# Tennessee          72
# Nebraska           72
# Maine              72
# Idaho              72
# Alaska             72
# ...

# %%
Adidas["Total Sales"]
# Out:
# 0       600000.0
# 1       500000.0
# 2       400000.0
# 3       382500.0
# 4       540000.0
#           ...
# 4107      8385.0
# 4108      7436.0
# 4109      6232.0
# 4110      5198.0
# 4111      7216.0
# Name: Total Sales, Length: 4112, dtype: float64

# %%
#sum of the sales

# %%
total_sales = Adidas["Total Sales"].sum()

total_sales
# Out:
# 868889650.0

# %%
#state wise sales

# %%
plt.figure(figsize=(5,5))
plt.bar(list(Adidas["State"].value_counts()[0:5].keys()),list(Adidas["Total Sales"][0:5]))
plt.show()

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732   2020-01-01  Northeast    New York
# 1     Foot Locker      1185732   2020-01-02  Northeast    New York
# 2     Foot Locker      1185732   2020-01-03  Northeast    New York
# 3     Foot Locker      1185732   2020-01-04  Northeast    New York
# 4     Foot Locker      1185732   2020-01-05  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833   2021-03-14       West  California
# 4108       Kohl's      1189833   2021-03-15       West  California
# 4109       Kohl's      1189833   2021-03-16       West  California
# 4110       Kohl's      1189833   2021-03-17       West  California
# 4111       Kohl's      1189833   2021-03-18       West  California
#
#              City                    Product  Price per Unit  Units Sold  \
# 0        New York      Men's Street Footwear            50.0      1200.0
# ...

# %%
Adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4112 entries, 0 to 4111
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          4112 non-null   object
#  1   Retailer ID       4112 non-null   int64
#  2   Invoice Date      4112 non-null   datetime64[ns]
#  3   Region            4112 non-null   object
#  4   State             4112 non-null   object
#  5   City              4112 non-null   object
#  6   Product           4112 non-null   object
#  7   Price per Unit    4112 non-null   float64
#  8   Units Sold        4112 non-null   float64
#  9   Total Sales       4112 non-null   float64
#  10  Operating Profit  4112 non-null   object
#  11  Operating Margin  4112 non-null   object
#  12  Sales Method      4112 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 417.8+ KB

# %%
#types of sales method

# %%
Adidas["Sales Method"].value_counts()
# Out:
# Sales Method
# In-store    1740
# Online      1225
# Outlet      1147
# Name: count, dtype: int64

# %%
#types of sales method pie chart

# %%
plt.figure(figsize=(5,5))
plt.pie(list(Adidas["Sales Method"].value_counts()),labels=list(Adidas["Sales Method"].value_counts().keys()),autopct="%0.1f%%")
plt.show()

# %%
Adidas["Product"].value_counts()
# Out:
# Product
# Men's Street Footwear        686
# Men's Athletic Footwear      686
# Women's Apparel              686
# Women's Street Footwear      685
# Men's Apparel                685
# Women's Athletic Footwear    684
# Name: count, dtype: int64

# %%
#maximum oprating profit

# %%
Adidas["Operating Profit"].max()
# Out:
# '$99,750 '

# %%
#minimum oprating profit

# %%
Adidas["Operating Profit"].min()
# Out:
# '$0 '

# %%
#West region data

# %%
west_region=Adidas[Adidas["Region"] == "West"]

# %%
west_region
# Out:
#        Retailer  Retailer ID Invoice Date Region       State           City  \
# 144   West Gear      1128299   2020-11-05   West  California  San Francisco
# 145   West Gear      1128299   2020-11-06   West  California  San Francisco
# 146   West Gear      1128299   2020-11-07   West  California  San Francisco
# 147   West Gear      1128299   2020-11-08   West  California  San Francisco
# 148   West Gear      1128299   2020-11-09   West  California  San Francisco
# ...         ...          ...          ...    ...         ...            ...
# 4107     Kohl's      1189833   2021-03-14   West  California    Los Angeles
# 4108     Kohl's      1189833   2021-03-15   West  California    Los Angeles
# 4109     Kohl's      1189833   2021-03-16   West  California    Los Angeles
# 4110     Kohl's      1189833   2021-03-17   West  California    Los Angeles
# 4111     Kohl's      1189833   2021-03-18   West  California    Los Angeles
#
# ...

# %%
#creating the new month column on the basis of invoice date

# %%
west_region["month"] = west_region["Invoice Date"].dt.month_name()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\2248167274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_region["month"] = west_region["Invoice Date"].dt.month_name()

# %%
west_region
# Out:
#        Retailer  Retailer ID Invoice Date Region       State           City  \
# 144   West Gear      1128299   2020-11-05   West  California  San Francisco
# 145   West Gear      1128299   2020-11-06   West  California  San Francisco
# 146   West Gear      1128299   2020-11-07   West  California  San Francisco
# 147   West Gear      1128299   2020-11-08   West  California  San Francisco
# 148   West Gear      1128299   2020-11-09   West  California  San Francisco
# ...         ...          ...          ...    ...         ...            ...
# 4107     Kohl's      1189833   2021-03-14   West  California    Los Angeles
# 4108     Kohl's      1189833   2021-03-15   West  California    Los Angeles
# 4109     Kohl's      1189833   2021-03-16   West  California    Los Angeles
# 4110     Kohl's      1189833   2021-03-17   West  California    Los Angeles
# 4111     Kohl's      1189833   2021-03-18   West  California    Los Angeles
#
# ...

# %%
west_region["month"]
# Out:
# 144     November
# 145     November
# 146     November
# 147     November
# 148     November
#           ...
# 4107       March
# 4108       March
# 4109       March
# 4110       March
# 4111       March
# Name: month, Length: 1016, dtype: object

# %%
#sorting total sales column of an west reion

# %%
west_region.sort_values(by=["Total Sales"] , ascending=False,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\3772388266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_region.sort_values(by=["Total Sales"] , ascending=False,inplace=True)

# %%
west_region
# Out:
#        Retailer  Retailer ID Invoice Date Region       State           City  \
# 1898  West Gear      1128299   2021-06-24   West      Oregon       Portland
# 1899  West Gear      1128299   2021-07-23   West      Oregon       Portland
# 1905  West Gear      1128299   2021-08-24   West      Oregon       Portland
# 175   West Gear      1128299   2021-01-11   West  California  San Francisco
# 679   West Gear      1128299   2020-06-30   West  Washington        Seattle
# ...         ...          ...          ...    ...         ...            ...
# 4038  West Gear      1128299   2020-11-11   West  California  San Francisco
# 4103     Kohl's      1189833   2021-03-10   West  California  San Francisco
# 4100     Kohl's      1189833   2021-02-17   West  California  San Francisco
# 4109     Kohl's      1189833   2021-03-16   West  California    Los Angeles
# 4110     Kohl's      1189833   2021-03-17   West  California    Los Angeles
#
# ...

# %%
west_region["month"]
# Out:
# 1898        June
# 1899        July
# 1905      August
# 175      January
# 679         June
#           ...
# 4038    November
# 4103       March
# 4100    February
# 4109       March
# 4110       March
# Name: month, Length: 1016, dtype: object

# %%
west_region["Total Sales"]
# Out:
# 1898    735000.0
# 1899    722500.0
# 1905    720000.0
# 175     700000.0
# 679     675000.0
#           ...
# 4038      7000.0
# 4103      6560.0
# 4100      6496.0
# 4109      6232.0
# 4110      5198.0
# Name: Total Sales, Length: 1016, dtype: float64

# %%
#monthwise sales visulize through pie chart

# %%
plt.figure(figsize=(5,5))
plt.pie(list(west_region["Total Sales"][0:10]),labels=list(west_region["month"][0:10].keys()),autopct="%0.1f%%")
plt.title("West regions monthwise sale")
plt.show()

# %%
#Maximum sale in west region

# %%
west_region["Total Sales"].max()
# Out:
# 735000.0

# %%
#maximum,minimum,average value of an Price per Unit,Units Sold,Total Sales

# %%
describe=["Price per Unit","Units Sold","Total Sales"]
west_region[describe].describe()
# Out:
#        Price per Unit   Units Sold    Total Sales
# count     1016.000000  1016.000000    1016.000000
# mean        55.283465   471.407480  256267.521654
# std         14.747409   188.984794  148464.483140
# min         10.000000   100.000000    5198.000000
# 25%         45.000000   325.000000  150000.000000
# 50%         55.000000   450.000000  240000.000000
# 75%         65.000000   600.000000  357500.000000
# max        105.000000  1050.000000  735000.000000

# %%
#display north region data of an Adidas data

# %%
north=Adidas[Adidas["Region"] == "Northeast"]

# %%
north
# Out:
#            Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0       Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1       Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2       Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3       Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4       Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# ...             ...          ...          ...        ...       ...       ...
# 3955        Walmart      1185732   2020-07-18  Northeast  New York  New York
# 3956  Sports Direct      1197831   2020-07-19  Northeast  New York  New York
# 3957  Sports Direct      1197831   2020-07-20  Northeast  New York  New York
# 3958  Sports Direct      1197831   2020-07-21  Northeast  New York  New York
# 3959  Sports Direct      1197831   2020-07-22  Northeast  New York  New York
#
# ...

# %%
#sort the total values in descending order

# %%
north.sort_values(by="Total Sales" , ascending=False)
# Out:
#            Retailer  Retailer ID Invoice Date     Region         State  \
# 62          Walmart      1185732   2020-05-03  Northeast      New York
# 36      Foot Locker      1185732   2020-03-10  Northeast      New York
# 30      Foot Locker      1185732   2020-03-04  Northeast      New York
# 42      Foot Locker      1185732   2020-03-16  Northeast      New York
# 56          Walmart      1185732   2020-04-27  Northeast      New York
# ...             ...          ...          ...        ...           ...
# 3318      West Gear      1185732   2021-03-20  Northeast      Maryland
# 3606    Foot Locker      1185732   2021-03-06  Northeast  Rhode Island
# 3958  Sports Direct      1197831   2020-07-21  Northeast      New York
# 3959  Sports Direct      1197831   2020-07-22  Northeast      New York
# 3956  Sports Direct      1197831   2020-07-19  Northeast      New York
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
#check the data tabuler format or not

# %%
north.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1008 entries, 0 to 3959
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          1008 non-null   object
#  1   Retailer ID       1008 non-null   int64
#  2   Invoice Date      1008 non-null   datetime64[ns]
#  3   Region            1008 non-null   object
#  4   State             1008 non-null   object
#  5   City              1008 non-null   object
#  6   Product           1008 non-null   object
#  7   Price per Unit    1008 non-null   float64
#  8   Units Sold        1008 non-null   float64
#  9   Total Sales       1008 non-null   float64
#  10  Operating Profit  1008 non-null   object
#  11  Operating Margin  1008 non-null   object
#  12  Sales Method      1008 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 110.2+ KB

# %%
#Add the new column in the north region data

# %%
north["year"] = north["Invoice Date"].dt.year
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\125085966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north["year"] = north["Invoice Date"].dt.year

# %%
#count the types of retailer in the north region data

# %%
north["Retailer"].value_counts()[0:5]
# Out:
# Retailer
# Foot Locker      357
# Amazon           203
# Sports Direct    172
# West Gear        147
# Kohl's            85
# Name: count, dtype: int64

# %%
#Analyse the total sales column from north region data

# %%
north["Total Sales"][0:5]
# Out:
# 0    600000.0
# 1    500000.0
# 2    400000.0
# 3    382500.0
# 4    540000.0
# Name: Total Sales, dtype: float64

# %%
#Retailer wise sales

# %%
plt.figure(figsize=(9,5))
plt.bar(list(north["Retailer"].value_counts()[0:5].keys()),list(north["Total Sales"][0:5]),color=["red","orange","gray","blue","yellow"])
plt.title("most Retailer")
plt.show()

# %%
north
# Out:
#            Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0       Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1       Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2       Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3       Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4       Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# ...             ...          ...          ...        ...       ...       ...
# 3955        Walmart      1185732   2020-07-18  Northeast  New York  New York
# 3956  Sports Direct      1197831   2020-07-19  Northeast  New York  New York
# 3957  Sports Direct      1197831   2020-07-20  Northeast  New York  New York
# 3958  Sports Direct      1197831   2020-07-21  Northeast  New York  New York
# 3959  Sports Direct      1197831   2020-07-22  Northeast  New York  New York
#
# ...

# %%
#sort north region data by total sales

# %%
north.sort_values(by="Total Sales",ascending=False ,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\2721204864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north.sort_values(by="Total Sales",ascending=False ,inplace=True)

# %%
north
# Out:
#            Retailer  Retailer ID Invoice Date     Region         State  \
# 62          Walmart      1185732   2020-05-03  Northeast      New York
# 36      Foot Locker      1185732   2020-03-10  Northeast      New York
# 30      Foot Locker      1185732   2020-03-04  Northeast      New York
# 42      Foot Locker      1185732   2020-03-16  Northeast      New York
# 56          Walmart      1185732   2020-04-27  Northeast      New York
# ...             ...          ...          ...        ...           ...
# 3318      West Gear      1185732   2021-03-20  Northeast      Maryland
# 3606    Foot Locker      1185732   2021-03-06  Northeast  Rhode Island
# 3958  Sports Direct      1197831   2020-07-21  Northeast      New York
# 3959  Sports Direct      1197831   2020-07-22  Northeast      New York
# 3956  Sports Direct      1197831   2020-07-19  Northeast      New York
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %%
north["Total Sales"]
# Out:
# 62      780000.0
# 36      765000.0
# 30      750000.0
# 42      750000.0
# 56      747500.0
#           ...
# 3318      7500.0
# 3606      7500.0
# 3958      6930.0
# 3959      5950.0
# 3956      5616.0
# Name: Total Sales, Length: 1008, dtype: float64

# %%
north["year"]
# Out:
# 62      2020
# 36      2020
# 30      2020
# 42      2020
# 56      2020
#         ...
# 3318    2021
# 3606    2021
# 3958    2020
# 3959    2020
# 3956    2020
# Name: year, Length: 1008, dtype: int32

# %%
#creating new west region data on basis of Adidas data

# %%
west=Adidas[Adidas["Region"] == "Midwest"]

# %%
west
# Out:
#          Retailer  Retailer ID Invoice Date   Region     State          City  \
# 288   Foot Locker      1185732   2021-06-04  Midwest  Illinois       Chicago
# 289   Foot Locker      1185732   2021-06-05  Midwest  Illinois       Chicago
# 290   Foot Locker      1185732   2021-06-06  Midwest  Illinois       Chicago
# 291   Foot Locker      1185732   2021-06-07  Midwest  Illinois       Chicago
# 292   Foot Locker      1185732   2021-06-08  Midwest  Illinois       Chicago
# ...           ...          ...          ...      ...       ...           ...
# 3235    West Gear      1185732   2021-01-17  Midwest   Indiana  Indianapolis
# 3236    West Gear      1185732   2021-01-17  Midwest   Indiana  Indianapolis
# 3237    West Gear      1185732   2021-02-17  Midwest   Indiana  Indianapolis
# 3238    West Gear      1185732   2021-02-17  Midwest   Indiana  Indianapolis
# 3239    West Gear      1185732   2021-02-17  Midwest   Indiana  Indianapolis
#
# ...

# %%
#sorting the total values column from west region data

# %%
west.sort_values(by="Total Sales", ascending=False , inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\2920945824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west.sort_values(by="Total Sales", ascending=False , inplace=True)

# %%
west
# Out:
#            Retailer  Retailer ID Invoice Date   Region      State  \
# 2505         Amazon      1185732   2021-12-09  Midwest       Ohio
# 2475         Amazon      1185732   2021-07-09  Midwest       Ohio
# 2481         Amazon      1185732   2021-08-10  Midwest       Ohio
# 1683  Sports Direct      1185732   2021-07-15  Midwest   Michigan
# 1689  Sports Direct      1185732   2021-08-16  Midwest   Michigan
# ...             ...          ...          ...      ...        ...
# 809     Foot Locker      1185732   2020-11-07  Midwest  Minnesota
# 803     Foot Locker      1185732   2020-11-01  Midwest  Minnesota
# 1061    Foot Locker      1185732   2021-07-17  Midwest   Nebraska
# 1019    Foot Locker      1185732   2021-06-05  Midwest   Nebraska
# 1025    Foot Locker      1185732   2021-06-11  Midwest   Nebraska
#
#              City                    Product  Price per Unit  Units Sold  \
# 2505     Columbus      Men's Street Footwear            75.0       825.0
# ...

# %%
#find the maximum,minimum,average of an aggregate columns

# %%
west.describe()
# Out:
#         Retailer ID                   Invoice Date  Price per Unit  \
# count  9.360000e+02                            936      936.000000
# mean   1.187017e+06  2021-05-31 08:46:09.230769152       41.570513
# min    1.185732e+06            2020-10-21 00:00:00       10.000000
# 25%    1.185732e+06            2021-02-23 18:00:00       35.000000
# 50%    1.185732e+06            2021-06-11 00:00:00       40.000000
# 75%    1.185732e+06            2021-08-13 00:00:00       50.000000
# max    1.197831e+06            2021-12-17 00:00:00       80.000000
# std    3.374085e+03                            NaN       12.394640
#
#        Units Sold    Total Sales
# count  936.000000     936.000000
# mean   327.612179  141412.660256
# min      0.000000       0.000000
# 25%    200.000000   70000.000000
# 50%    300.000000  113125.000000
# 75%    455.000000  192500.000000
# max    900.000000  618750.000000
# std    173.401448   97423.109939

# %%
#finding the maximum total sale of an west region

# %%
west["Total Sales"].max()
# Out:
# 618750.0

# %%
west["Units Sold"]
# Out:
# 2505    825.0
# 2475    900.0
# 2481    875.0
# 1683    900.0
# 1689    875.0
#         ...
# 809      25.0
# 803      25.0
# 1061     25.0
# 1019      0.0
# 1025      0.0
# Name: Units Sold, Length: 936, dtype: float64

# %%
west["Total Sales"]
# Out:
# 2505    618750.0
# 2475    585000.0
# 2481    568750.0
# 1683    540000.0
# 1689    525000.0
#           ...
# 809       8750.0
# 803       8750.0
# 1061      7500.0
# 1019         0.0
# 1025         0.0
# Name: Total Sales, Length: 936, dtype: float64

# %%
#Analyse the data through scatter plot

# %%
x = np.array(west["Units Sold"][0:20])
y = np.array(west["Total Sales"][0:20])

plt.scatter(x, y, color="orange")
plt.show()

# %%
#creating the new column of month name from invice date column

# %%
west["month"]=west["Invoice Date"].dt.month_name()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16112\2909723788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west["month"]=west["Invoice Date"].dt.month_name()

# %%
west
# Out:
#            Retailer  Retailer ID Invoice Date   Region      State  \
# 2505         Amazon      1185732   2021-12-09  Midwest       Ohio
# 2475         Amazon      1185732   2021-07-09  Midwest       Ohio
# 2481         Amazon      1185732   2021-08-10  Midwest       Ohio
# 1683  Sports Direct      1185732   2021-07-15  Midwest   Michigan
# 1689  Sports Direct      1185732   2021-08-16  Midwest   Michigan
# ...             ...          ...          ...      ...        ...
# 809     Foot Locker      1185732   2020-11-07  Midwest  Minnesota
# 803     Foot Locker      1185732   2020-11-01  Midwest  Minnesota
# 1061    Foot Locker      1185732   2021-07-17  Midwest   Nebraska
# 1019    Foot Locker      1185732   2021-06-05  Midwest   Nebraska
# 1025    Foot Locker      1185732   2021-06-11  Midwest   Nebraska
#
#              City                    Product  Price per Unit  Units Sold  \
# 2505     Columbus      Men's Street Footwear            75.0       825.0
# ...

# %%
west["Total Sales"]
# Out:
# 2505    618750.0
# 2475    585000.0
# 2481    568750.0
# 1683    540000.0
# 1689    525000.0
#           ...
# 809       8750.0
# 803       8750.0
# 1061      7500.0
# 1019         0.0
# 1025         0.0
# Name: Total Sales, Length: 936, dtype: float64

# %%
group=west.groupby("month")

# %%
west["month"].value_counts()
# Out:
# month
# July         116
# June         111
# December      85
# January       85
# November      84
# February      82
# August        72
# March         67
# October       65
# May           61
# September     54
# April         54
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(west["month"][0:5].keys()),list(west["Total Sales"][0:5]))
plt.show()

# %%
group

# %%
west
# Out:
#            Retailer  Retailer ID Invoice Date   Region      State  \
# 2505         Amazon      1185732   2021-12-09  Midwest       Ohio
# 2475         Amazon      1185732   2021-07-09  Midwest       Ohio
# 2481         Amazon      1185732   2021-08-10  Midwest       Ohio
# 1683  Sports Direct      1185732   2021-07-15  Midwest   Michigan
# 1689  Sports Direct      1185732   2021-08-16  Midwest   Michigan
# ...             ...          ...          ...      ...        ...
# 809     Foot Locker      1185732   2020-11-07  Midwest  Minnesota
# 803     Foot Locker      1185732   2020-11-01  Midwest  Minnesota
# 1061    Foot Locker      1185732   2021-07-17  Midwest   Nebraska
# 1019    Foot Locker      1185732   2021-06-05  Midwest   Nebraska
# 1025    Foot Locker      1185732   2021-06-11  Midwest   Nebraska
#
#              City                    Product  Price per Unit  Units Sold  \
# 2505     Columbus      Men's Street Footwear            75.0       825.0
# ...

# %%
south=Adidas[Adidas["Region"] == "South"]

# %%
south
# Out:
#            Retailer  Retailer ID Invoice Date Region  State     City  \
# 72    Sports Direct      1197831   2020-07-23  South  Texas  Houston
# 73    Sports Direct      1197831   2020-07-24  South  Texas  Houston
# 74    Sports Direct      1197831   2020-07-25  South  Texas  Houston
# 75    Sports Direct      1197831   2020-07-26  South  Texas  Houston
# 76    Sports Direct      1197831   2020-07-27  South  Texas  Houston
# ...             ...          ...          ...    ...    ...      ...
# 4027        Walmart      1197831   2020-10-31  South  Texas  Houston
# 4028      West Gear      1128299   2020-11-01  South  Texas  Houston
# 4029      West Gear      1128299   2020-11-02  South  Texas  Houston
# 4030      West Gear      1128299   2020-11-03  South  Texas  Houston
# 4031      West Gear      1128299   2020-11-04  South  Texas  Houston
#
#                         Product  Price per Unit  Units Sold  Total Sales  \
# ...

# %%
south.sort_values(by="Total Sales" , ascending=False)
# Out:
#            Retailer  Retailer ID Invoice Date Region      State         City  \
# 1970      West Gear      1128299   2021-06-17  South  Louisiana  New Orleans
# 1971      West Gear      1128299   2021-07-16  South  Louisiana  New Orleans
# 1977      West Gear      1128299   2021-08-17  South  Louisiana  New Orleans
# 1976      West Gear      1128299   2021-07-16  South  Louisiana  New Orleans
# 1972      West Gear      1128299   2021-07-16  South  Louisiana  New Orleans
# ...             ...          ...          ...    ...        ...          ...
# 3964  Sports Direct      1197831   2020-07-27  South      Texas      Houston
# 3960  Sports Direct      1197831   2020-07-23  South      Texas      Houston
# 3972  Sports Direct      1197831   2020-08-04  South      Texas      Houston
# 3962  Sports Direct      1197831   2020-07-25  South      Texas      Houston
# 3966  Sports Direct      1197831   2020-07-29  South      Texas      Houston
#
# ...

# %%
south.describe()
# Out:
#         Retailer ID         Invoice Date  Price per Unit   Units Sold  \
# count  6.480000e+02                  648      648.000000   648.000000
# mean   1.188812e+06  2021-05-05 00:46:40       42.709877   498.824074
# min    1.128299e+06  2020-07-23 00:00:00       10.000000    75.000000
# 25%    1.197831e+06  2021-01-23 00:00:00       35.000000   325.000000
# 50%    1.197831e+06  2021-05-19 00:00:00       40.000000   475.000000
# 75%    1.197831e+06  2021-09-16 00:00:00       50.000000   650.000000
# max    1.197831e+06  2021-12-19 00:00:00      110.000000  1100.000000
# std    2.158821e+04                  NaN       15.734636   213.922670
#
#          Total Sales
# count     648.000000
# mean   213687.078704
# min      4750.000000
# 25%     97500.000000
# 50%    190625.000000
# 75%    310000.000000
# max    825000.000000
# std    152476.173374

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast    New York
# 1     Foot Locker      1185732     1/2/2020  Northeast    New York
# 2     Foot Locker      1185732     1/3/2020  Northeast    New York
# 3     Foot Locker      1185732     1/4/2020  Northeast    New York
# 4     Foot Locker      1185732     1/5/2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833    3/14/2021       West  California
# 4108       Kohl's      1189833    3/15/2021       West  California
# 4109       Kohl's      1189833    3/16/2021       West  California
# 4110       Kohl's      1189833    3/17/2021       West  California
# 4111       Kohl's      1189833    3/18/2021       West  California
#
#              City                    Product Price per Unit Units Sold  \
# 0        New York      Men's Street Footwear        $50.00       1,200
# ...

# %%
Adidas["State"].isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4107    False
# 4108    False
# 4109    False
# 4110    False
# 4111    False
# Name: State, Length: 4112, dtype: bool>

# %%
Adidas["State"]=Adidas["State"].fillna(0)

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast    New York
# 1     Foot Locker      1185732     1/2/2020  Northeast    New York
# 2     Foot Locker      1185732     1/3/2020  Northeast    New York
# 3     Foot Locker      1185732     1/4/2020  Northeast    New York
# 4     Foot Locker      1185732     1/5/2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833    3/14/2021       West  California
# 4108       Kohl's      1189833    3/15/2021       West  California
# 4109       Kohl's      1189833    3/16/2021       West  California
# 4110       Kohl's      1189833    3/17/2021       West  California
# 4111       Kohl's      1189833    3/18/2021       West  California
#
#              City                    Product Price per Unit Units Sold  \
# 0        New York      Men's Street Footwear        $50.00       1,200
# ...

# %%
Adidas.loc[2,"State"] = "india"

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast    New York
# 1     Foot Locker      1185732     1/2/2020  Northeast    New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       india
# 3     Foot Locker      1185732     1/4/2020  Northeast    New York
# 4     Foot Locker      1185732     1/5/2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833    3/14/2021       West  California
# 4108       Kohl's      1189833    3/15/2021       West  California
# 4109       Kohl's      1189833    3/16/2021       West  California
# 4110       Kohl's      1189833    3/17/2021       West  California
# 4111       Kohl's      1189833    3/18/2021       West  California
#
#              City                    Product Price per Unit Units Sold  \
# 0        New York      Men's Street Footwear        $50.00       1,200
# ...

# %%
Adidas["Total Sales"].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ...

# %%
Adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4112 entries, 0 to 4111
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          4112 non-null   object
#  1   Retailer ID       4112 non-null   int64
#  2   Invoice Date      4112 non-null   object
#  3   Region            4112 non-null   object
#  4   State             4112 non-null   object
#  5   City              4112 non-null   object
#  6   Product           4112 non-null   object
#  7   Price per Unit    4112 non-null   object
#  8   Units Sold        4112 non-null   object
#  9   Total Sales       4112 non-null   object
#  10  Operating Profit  4112 non-null   object
#  11  Operating Margin  4112 non-null   object
#  12  Sales Method      4112 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 417.8+ KB

# %%
Adidas["Total Sales"]=Adidas["Total Sales"].str.split("$")

# %%
Adidas
# Out:
#          Retailer  Retailer ID Invoice Date     Region       State  \
# 0     Foot Locker      1185732     1/1/2020  Northeast    New York
# 1     Foot Locker      1185732     1/2/2020  Northeast    New York
# 2     Foot Locker      1185732     1/3/2020  Northeast       india
# 3     Foot Locker      1185732     1/4/2020  Northeast    New York
# 4     Foot Locker      1185732     1/5/2020  Northeast    New York
# ...           ...          ...          ...        ...         ...
# 4107       Kohl's      1189833    3/14/2021       West  California
# 4108       Kohl's      1189833    3/15/2021       West  California
# 4109       Kohl's      1189833    3/16/2021       West  California
# 4110       Kohl's      1189833    3/17/2021       West  California
# 4111       Kohl's      1189833    3/18/2021       West  California
#
#              City                    Product Price per Unit Units Sold  \
# 0        New York      Men's Street Footwear        $50.00       1,200
# ...

# %%
Adidas["Total Sales"]
# Out:
# 0       [, 600,000 ]
# 1       [, 500,000 ]
# 2       [, 400,000 ]
# 3       [, 382,500 ]
# 4       [, 540,000 ]
#             ...
# 4107      [, 8,385 ]
# 4108      [, 7,436 ]
# 4109      [, 6,232 ]
# 4110      [, 5,198 ]
# 4111      [, 7,216 ]
# Name: Total Sales, Length: 4112, dtype: object

# %%
import seaborn as sns

# %%
sns.pairplot(Adidas)
plt.show()

# %%
Adidas.head(3)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732     1/1/2020  Northeast  New York  New York
# 1  Foot Locker      1185732     1/2/2020  Northeast  New York  New York
# 2  Foot Locker      1185732     1/3/2020  Northeast  New York  New York
#
#                    Product Price per Unit Units Sold Total Sales  \
# 0    Men's Street Footwear        $50.00       1,200   $600,000
# 1  Men's Athletic Footwear        $50.00       1,000   $500,000
# 2  Women's Street Footwear        $40.00       1,000   $400,000
#
#   Operating Profit Operating Margin Sales Method
# 0        $300,000               50%     In-store
# 1        $150,000               30%     In-store
# 2        $140,000               35%     In-store

# %%
Adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4112 entries, 0 to 4111
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          4112 non-null   object
#  1   Retailer ID       4112 non-null   int64
#  2   Invoice Date      4112 non-null   object
#  3   Region            4112 non-null   object
#  4   State             4112 non-null   object
#  5   City              4112 non-null   object
#  6   Product           4112 non-null   object
#  7   Price per Unit    4112 non-null   object
#  8   Units Sold        4112 non-null   object
#  9   Total Sales       4112 non-null   object
#  10  Operating Profit  4112 non-null   object
#  11  Operating Margin  4112 non-null   object
#  12  Sales Method      4112 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 417.8+ KB

# %%
Adidas["Units Sold"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 Adidas["Units Sold"].astype(float)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:451, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
sns.boxplot(Adidas["Retailer ID"],Adidas["City"], data=Adidas, )
sns.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sns.boxplot(Adidas["Retailer ID"],Adidas["City"], data=Adidas, )
#       2 sns.show()
#
# TypeError: boxplot() got multiple values for argument 'data'
